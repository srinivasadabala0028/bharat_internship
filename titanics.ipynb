# %%
# importing libraries
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns
import warnings 
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('titanico.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.shape
# Out:
# (891, 12)

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# replacing the age null values with mean of age 
mean_val=df['Age'].mean()
print(mean_val)
# Out:
# 29.69911764705882

# %%
df['Age'].fillna(mean_val,inplace=True)

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
#replacing the null values in embarked in column with mode 
ebd=df.groupby('Embarked')['Embarked'].count()
print(ebd)
# Out:
# Embarked
# C    168
# Q     77
# S    644
# Name: Embarked, dtype: int64

# %%
df['Embarked'].fillna('S',inplace=True)

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         0
# dtype: int64

# %%
# dropping the cabin column 
df.drop('Cabin',axis=1,inplace=True)
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %%
#relation between all the categorical variables 
cat_var=df.select_dtypes(include='object')
cat_stat=cat_var.describe().T
cat_stat
# Out:
#          count unique                      top freq
# Name       891    891  Braund, Mr. Owen Harris    1
# Sex        891      2                     male  577
# Ticket     891    681                   347082    7
# Embarked   891      3                        S  646

# %%
#relation between the all the numerical variables 
num_var=df.select_dtypes(exclude='object')
num_stat=num_var.describe().T
num_stat
# Out:
#              count        mean         std   min       25%         50%    75%  \
# PassengerId  891.0  446.000000  257.353842  1.00  223.5000  446.000000  668.5
# Survived     891.0    0.383838    0.486592  0.00    0.0000    0.000000    1.0
# Pclass       891.0    2.308642    0.836071  1.00    2.0000    3.000000    3.0
# Age          891.0   29.699118   13.002015  0.42   22.0000   29.699118   35.0
# SibSp        891.0    0.523008    1.102743  0.00    0.0000    0.000000    1.0
# Parch        891.0    0.381594    0.806057  0.00    0.0000    0.000000    0.0
# Fare         891.0   32.204208   49.693429  0.00    7.9104   14.454200   31.0
#
#                   max
# PassengerId  891.0000
# Survived       1.0000
# Pclass         3.0000
# Age           80.0000
# SibSp          8.0000
# Parch          6.0000
# Fare         512.3292

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %%
sns.set_style('dark')

# %%
sns.set_style('dark')
survived=df.groupby('Survived')['Survived'].count()
survived.plot(kind='pie',autopct='%1.1f%%')
plt.title('No of People survived')
# Out:
# Text(0.5, 1.0, 'No of People survived')

# %%
sns.set_style('dark')
sns.catplot(x='Sex',col='Survived', data=df,kind='count')

# %%
sale=df.groupby('Embarked')['Fare'].sum()
plt.figure(figsize=(8,6))
sale.plot(kind='bar',edgecolor='black')
plt.xticks(rotation=360)
plt.ylabel('sale',fontsize=16)
plt.title('Sales Per each Region')
# Out:
# Text(0.5, 1.0, 'Sales Per each Region')

# %%
sns.stripplot(x=df['Pclass'],y=df['Fare'],palette='Set1',linewidth=0.6)
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='Fare'>

# %%
sns.histplot(df['Age'],kde=False)
plt.title('No of People In Each Age Group')
# Out:
# Text(0.5, 1.0, 'No of People In Each Age Group')

# %%
plt.scatter(df['Sex'],df['Age'],s=20,cmap='viridis', marker='o')

# %%
data = {
    'a': df['Embarked'],
    'b': df['Sex']
}

pl = pd.DataFrame(data)
pl = pl.groupby(['a', 'b']).size().unstack(fill_value=0)
print(pl)
pl.plot(kind='bar',stacked=True)
plt.ylabel('count')
plt.xlabel('place')
plt.xticks(rotation=360)
plt.title('Sex ratio From Each Place')
plt.legend(title='b')
# Out:
# b  female  male
# a
# C      73    95
# Q      36    41
# S     205   441

# %%
df
plt.scatter(df['Survived'],df['Fare'],cmap='viridis',marker='o',edgecolor='black')
o=[0,1]
plt.xticks(o)
plt.xlabel('survived')
plt.ylabel('fare')
plt.title('survival rate by fare')
# Out:
# Text(0.5, 1.0, 'survival rate by fare')

# %%
sns.catplot(data=df,x='Pclass',hue='Survived',kind='count')
plt.legend(title='Survived', labels=['No', 'Yes'])

# %%
plt.scatter(df['Age'],df['SibSp'],marker='*',edgecolor='blue')
plt.xlabel('Age')
plt.ylabel('siblings')
plt.title('no of siblings for each age group ')
# Out:
# Text(0.5, 1.0, 'no of siblings for each age group ')

# %%
plt.scatter(df['Age'],df['Parch'],marker='h',edgecolor='blue')
plt.xlabel('Age')
plt.ylabel('siblings')
plt.title('no of siblings for each age group ')
# Out:
# Text(0.5, 1.0, 'no of siblings for each age group ')

# %%
sns.histplot(df['Fare'],color='black',kde=True)
# Out:
# <AxesSubplot:xlabel='Fare', ylabel='Count'>

# %%
sns.boxplot(x='Survived',y='Fare',data=df,palette='Set2' )
plt.title('survived people for each fare')
# Out:
# Text(0.5, 1.0, 'survived people for each fare')

# %%
emb_map={ 'S':1,'Q':2,'C':3}
df['Embarked']=df['Embarked'].map(emb_map)
sex_map={ 'male':1,'female':2}
df['Sex']=df['Sex'].map(sex_map)
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    1  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    2  38.0      1      0
# 2                             Heikkinen, Miss. Laina    2  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    2  35.0      1      0
# 4                           Allen, Mr. William Henry    1  35.0      0      0
#
#              Ticket     Fare  Embarked
# 0         A/5 21171   7.2500         1
# 1          PC 17599  71.2833         3
# 2  STON/O2. 3101282   7.9250         1
# 3            113803  53.1000         1
# 4            373450   8.0500         1

# %%
corr_matrix=df.corr()
sns.heatmap(corr_matrix,annot=True)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(20,20))
sns.pairplot(df)

# %%
#featurem seelection 
df.drop(columns=['PassengerId','Name','Ticket'],axis=1,inplace=True)

# %%
df
y=df['Survived']
X=df.drop(columns=['Survived'],axis=1)
print(X)
# Out:
#      Pclass  Sex        Age  SibSp  Parch     Fare  Embarked
# 0         3    1  22.000000      1      0   7.2500         1
# 1         1    2  38.000000      1      0  71.2833         3
# 2         3    2  26.000000      0      0   7.9250         1
# 3         1    2  35.000000      1      0  53.1000         1
# 4         3    1  35.000000      0      0   8.0500         1
# ..      ...  ...        ...    ...    ...      ...       ...
# 886       2    1  27.000000      0      0  13.0000         1
# 887       1    2  19.000000      0      0  30.0000         1
# 888       3    2  29.699118      1      2  23.4500         1
# 889       1    1  26.000000      0      0  30.0000         3
# 890       3    1  32.000000      0      0   7.7500         2
#
# [891 rows x 7 columns]

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
ct = ColumnTransformer(transformers=[('encoder', OneHotEncoder(), [0])], remainder='passthrough')
X = np.array(ct.fit_transform(X))

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
y = le.fit_transform(y)

# %%
# Importing Classifier Modules
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier,ExtraTreeClassifier
from sklearn.ensemble import RandomForestClassifier,ExtraTreesClassifier,BaggingClassifier,AdaBoostClassifier,GradientBoostingClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC

# %%
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
k_fold = KFold(n_splits=10, shuffle=True, random_state=0)

# %%
clf = KNeighborsClassifier(n_neighbors = 13)
scoring = 'accuracy'
score = cross_val_score(clf, X, y, cv=k_fold, n_jobs=1, scoring=scoring)
print(score)
# Out:
# [0.76666667 0.78651685 0.69662921 0.66292135 0.68539326 0.71910112
#  0.73033708 0.75280899 0.69662921 0.69662921]

# %%
clf = [KNeighborsClassifier(n_neighbors = 13),DecisionTreeClassifier(),
       RandomForestClassifier(n_estimators=13),GaussianNB(),SVC(),ExtraTreeClassifier(),
      GradientBoostingClassifier(n_estimators=10, learning_rate=1,max_features=3, max_depth =3, random_state = 10),AdaBoostClassifier(),ExtraTreesClassifier()]
def model_fit():
    scoring = 'accuracy'
    for i in range(len(clf)):
        score = cross_val_score(clf[i], X, y, cv=k_fold, n_jobs=1, scoring=scoring)
        print("Score of Model",i,":",round(np.mean(score)*100,2))

model_fit()
# Out:
# Score of Model 0 : 71.94
# Score of Model 1 : 77.67
# Score of Model 2 : 79.8
# Score of Model 3 : 75.98
# Score of Model 4 : 68.01
# Score of Model 5 : 77.56
# Score of Model 6 : 80.36
# Score of Model 7 : 80.13
# Score of Model 8 : 79.8
